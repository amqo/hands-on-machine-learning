# %%
import numpy as np

m = 100
X = 6 * np.random.rand(m, 1) - 3

# %%
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(X, y)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

poly_features = PolynomialFeatures(degree = 2, include_bias=False)

poly_model = make_pipeline(poly_features, LinearRegression())
poly_model.fit(X, y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(include_bias=False)),
#                 ('linearregression', LinearRegression())])

# %%
fig = plt.figure()
ax = plt.axes()

ax.set(xlabel='X', ylabel='y', title='Polynomial Regression')
ax.scatter(X, y, s=10, color='b')

X_sort = X.copy()
X_sort.sort(axis=0)
ax.plot(X_sort, poly_model.predict(X_sort), 'r-', label='Predictions', alpha=0.7)
ax.legend()
