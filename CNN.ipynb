# %%
from matplotlib.image import imread
import numpy as np
import os

# %%
flower = imread(os.path.join("images", "flower.jpeg")) / 255
images = np.array([flower])

# %%
batch_size, height, width, channels = images.shape
images.shape
# Out:
# (1, 670, 1000, 3)

# %%
filters = np.zeros(shape=(7, 7, channels, 2), dtype=np.float32)
filters[:, 3, :, 0] = 1
filters[3, :, :, 1] = 1

# %%
import tensorflow as tf
outputs = tf.nn.conv2d(images, filters, strides=1, padding="SAME")
# Out:
# Metal device set to: Apple M1 Max
# 2022-10-03 19:06:35.824868: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-03 19:06:35.824982: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import matplotlib.pyplot as plt
plt.imshow(outputs[0, :, :, 1], cmap="gray")
plt.axis("off")
plt.show()
